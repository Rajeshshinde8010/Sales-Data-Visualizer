# %%
# ==========================
# SALES DATA VISUALIZER
# ==========================

import pandas as pd
import matplotlib.pyplot as plt

# Load CSV File
df = pd.read_csv("sales_data.csv")

# Show Dataset
print("Sales Dataset:\n")
print(df)

# Monthly Sales Total
monthly_sales = df.groupby("Month")["Sales"].sum()

# Bar Chart
plt.figure(figsize=(8,5))
monthly_sales.plot(kind="bar")

plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Monthly Sales Analysis")

plt.show()

# Line Chart
plt.figure(figsize=(8,5))
monthly_sales.plot(kind="line", marker="o")

plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Sales Trend")

plt.show()
# Out:
# Sales Dataset:
#
#   Month Product  Sales  Profit
# 0   Jan  Laptop  50000   10000
# 1   Feb  Mobile  40000    8000
# 2   Mar  Tablet  30000    6000
# 3   Apr  Laptop  55000   12000
# 4   May  Mobile  42000    8500
# 5   Jun  Tablet  32000    6500
# 6   Jul  Laptop  60000   13000
# 7   Aug  Mobile  45000    9000
